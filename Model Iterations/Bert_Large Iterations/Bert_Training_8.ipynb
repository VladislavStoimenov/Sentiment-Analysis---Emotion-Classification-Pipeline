# %% [markdown]
# # Bert large | 56 tokens | 1e-5 | 6 + neutral = Macro F1 - 0.40 / Weighted F1 - 0.49 | Custom Weights V2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import os
from transformers import AutoTokenizer, BertForSequenceClassification, Trainer, TrainingArguments, AutoModelForSequenceClassification
import torch
from torch.utils.data import Dataset
from sklearn.metrics import f1_score, accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv("final_combined_dataset_sentence&emotion_only.csv")

# Label mapping
unique_emotions = df["emotion"].unique()
label2id = {label: idx for idx, label in enumerate(sorted(unique_emotions))}
id2label = {idx: label for label, idx in label2id.items()}

# Apply mapping
df["label"] = df["emotion"].map(label2id)

# Stratified split
train_df, val_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df["label"],
    random_state=42
)

# Manually defined class weights
class_weights_dict = {
    0: 2.5,   # anger (was 2.0)
    1: 8.0,   # disgust (was 10.0)
    2: 4.0,   # fear (↑ to help improve weak recall)
    3: 1.5,   # happiness (↑ slightly)
    4: 0.5,   # neutral (↓ it's dominating predictions)
    5: 3.5,   # sadness (↑ underpredicted)
    6: 4.0    # surprise (↑ underpredicted and rare)
}


# Print for verification
print("Preprocessing complete!")
print(f"Train size: {len(train_df)}")
print(f"Val size: {len(val_df)}")
print("Label2ID:", label2id)
print("Class Weights:", class_weights_dict)
# Out:
# Preprocessing complete!
# Train size: 370583
# Val size: 92646
# Label2ID: {'anger': 0, 'disgust': 1, 'fear': 2, 'happiness': 3, 'neutral': 4, 'sadness': 5, 'surprise': 6}
# Class Weights: {0: 2.5, 1: 8.0, 2: 4.0, 3: 1.5, 4: 0.5, 5: 3.5, 6: 4.0}

# %%
# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased")

# Tokenization function
def tokenize_data(sentences, labels):
    encodings = tokenizer(
        sentences.tolist(),
        padding=True,
        truncation=True,
        max_length=56,
        return_tensors="pt"
    )
    return encodings, torch.tensor(labels.tolist())

# Tokenize train and validation data
train_encodings, train_labels = tokenize_data(train_df["sentence"], train_df["label"])
val_encodings, val_labels = tokenize_data(val_df["sentence"], val_df["label"])

# Custom Dataset class
class EmotionDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item["labels"] = self.labels[idx]
        return item

    def __len__(self):
        return len(self.labels)

# Create dataset objects
train_dataset = EmotionDataset(train_encodings, train_labels)
val_dataset = EmotionDataset(val_encodings, val_labels)

print("Tokenization complete. Ready for training.")
# Out:
# Tokenization complete. Ready for training.

# %%
# Load model
model = BertForSequenceClassification.from_pretrained(
    "bert-large-uncased",
    num_labels=7,
    id2label=id2label,
    label2id=label2id
)

# Move to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Convert class weights to tensor
weights = torch.tensor(list(class_weights_dict.values()), dtype=torch.float).to(device)
loss_fn = torch.nn.CrossEntropyLoss(weight=weights)

# Custom compute_metrics function
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels, preds, average='macro')
    acc = accuracy_score(labels, preds)
    return {"macro_f1": f1, "accuracy": acc}

training_args = TrainingArguments(
    output_dir="checkpoints/bert_large_56_adjusted_weights",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="macro_f1",
    greater_is_better=True,
    save_total_limit=2,
    num_train_epochs=5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    learning_rate=1e-5,
    weight_decay=0.01,
    warmup_ratio=0.1,
    report_to="none",
    fp16=True
)




# Trainer with custom loss function
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits
        loss = loss_fn(logits, labels)
        return (loss, outputs) if return_outputs else loss


# Initialize trainer
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Train the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='57905' max='57905' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [57905/57905 1:28:07, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Macro F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.418300</td>
#       <td>0.235109</td>
#       <td>0.690541</td>
#       <td>0.876692</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.219300</td>
#       <td>0.233448</td>
#       <td>0.702186</td>
#       <td>0.879509</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.186600</td>
#       <td>0.257957</td>
#       <td>0.703324</td>
#       <td>0.881722</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.154600</td>
#       <td>0.285455</td>
#       <td>0.700907</td>
#       <td>0.879520</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.128200</td>
#       <td>0.337456</td>
#       <td>0.712438</td>
#       <td>0.883039</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=57905, training_loss=0.22141266119479103, metrics={'train_runtime': 5287.5119, 'train_samples_per_second': 350.432, 'train_steps_per_second': 10.951, 'total_flos': 1.8887080344722854e+17, 'train_loss': 0.22141266119479103, 'epoch': 5.0})

# %%
# Save the model and the tokenizer
trainer.save_model("bert_large_8")
tokenizer.save_pretrained("bert_large_8")
# Out:
# ('bert_large_8/tokenizer_config.json',
#  'bert_large_8/special_tokens_map.json',
#  'bert_large_8/vocab.txt',
#  'bert_large_8/added_tokens.json',
#  'bert_large_8/tokenizer.json')

# %%
# Emotion mapping provided by teacher
emotion_mapping = {
    "happiness": [
        "joy", "optimism", "approval", "pride", "gratitude", "confidence",
        "satisfaction", "hope", "love", "excitement", "caring", "relief", "admiration",
        "amusement", "anticipation", "encouragement", "desire", "happiness"
    ],
    "sadness": [
        "disappointment", "nostalgia", "remorse", "pain", "stress", "regret",
        "resignation", "despair", "confusion", "uncertainty", "sadness"
    ],
    "anger": [
        "anger", "annoyance", "disapproval", "frustration", "disbelief", "warning",
        "rejection"
    ],
    "disgust": ["disgust"],
    "fear": [
        "fear", "nervousness", "worry", "anxiety", "doubt", "insecurity", "urgency",
        "panic"
    ],
    "surprise": ["surprise", "realization", "shock", "amazement", "wonder"],
    "neutral": [
        "neutral", "mixed", "trust", "agreement", "instruction", "suggestion",
        "request", "confirmation", "acceptance", "reassurance", "clarification",
        "understanding", "certainty"
    ]
}

# Reverse the mapping for fast lookup
reverse_mapping = {sub: main for main, subs in emotion_mapping.items() for sub in subs}

# Load test data
df = pd.read_excel("group 24_url1.xlsx")

# Apply mapping
df["Mapped_Emotion"] = df["Emotion"].map(reverse_mapping)

# Drop rows with unmapped emotions (should be none if clean)
df = df.dropna(subset=["Mapped_Emotion"])

# Define label2id and id2label
core_emotions = ['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness', 'surprise']
label2id = {label: i for i, label in enumerate(core_emotions)}
id2label = {i: label for label, i in label2id.items()}

# Convert mapped emotion to numeric labels
df["label"] = df["Mapped_Emotion"].map(label2id)

# Tokenize
tokenizer = AutoTokenizer.from_pretrained("bert_large_8")
encodings = tokenizer(
    df["Translation"].tolist(),
    truncation=True,
    padding=True,
    max_length=56,
    return_tensors="pt"
)

# Dataset wrapper
class EmotionTestDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = torch.tensor(labels)

    def __getitem__(self, idx):
        item = {k: v[idx] for k, v in self.encodings.items()}
        item["labels"] = self.labels[idx]
        return item

    def __len__(self):
        return len(self.labels)

test_dataset = EmotionTestDataset(encodings, df["label"].tolist())

# Load trained model
model = AutoModelForSequenceClassification.from_pretrained("bert_large_8")

# Predict
trainer = Trainer(model=model)
predictions = trainer.predict(test_dataset)
y_pred = np.argmax(predictions.predictions, axis=1)
y_true = df["label"].tolist()

# Evaluation
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=core_emotions))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=core_emotions,
            yticklabels=core_emotions)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.57      0.46      0.51       217
#      disgust       0.25      0.50      0.33         2
#         fear       0.50      0.17      0.25        42
#    happiness       0.50      0.58      0.54       184
#      neutral       0.51      0.61      0.55       327
#      sadness       0.45      0.38      0.41       144
#     surprise       0.20      0.24      0.22        25
#
#     accuracy                           0.50       941
#    macro avg       0.43      0.42      0.40       941
# weighted avg       0.50      0.50      0.49       941

# %%
# Macro F1: unweighted mean across all classes
macro_f1 = f1_score(y_true, y_pred, average="macro")
print("Macro F1-score:", round(macro_f1, 4))
# Out:
# Macro F1-score: 0.4012

# %%
# Macro F1: unweighted mean across all classes
macro_f1 = f1_score(y_true, y_pred, average="weighted")
print("Weighted F1-score:", round(macro_f1, 4))
# Out:
# Weighted F1-score: 0.4945

# %%
from transformers import TrainerCallback
import matplotlib.pyplot as plt
import json
import os

# Load the training log file
log_path = os.path.join("checkpoints/bert_large_56/checkpoint-57905", "trainer_state.json")
with open(log_path, "r") as f:
    logs = json.load(f)

# Extract log history
history = logs["log_history"]

# Parse training and evaluation losses
train_steps = []
train_losses = []
eval_steps = []
eval_losses = []

for entry in history:
    if "loss" in entry and "step" in entry:
        train_steps.append(entry["step"])
        train_losses.append(entry["loss"])
    elif "eval_loss" in entry:
        eval_steps.append(entry["step"])
        eval_losses.append(entry["eval_loss"])

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(train_steps, train_losses, label="Training Loss")
plt.plot(eval_steps, eval_losses, label="Validation Loss", marker="o")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training & Validation Loss Over Time")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Reverse label mapping to get string labels
id2label = {v: k for k, v in label2id.items()}

# Add predictions to DataFrame
df["true_label"] = [id2label[i] for i in y_true]
df["predicted_label"] = [id2label[i] for i in y_pred]

# Filter for mismatches
false_predictions = df[df["true_label"] != df["predicted_label"]]

# Show sample of incorrect predictions
print("False predictions (sample):")
print(false_predictions[["Translation", "true_label", "predicted_label"]].sample(50, random_state=42))
# Out:
# False predictions (sample):
#                                             Translation true_label  \
# 105   She is angry, but I say these things for her g...      anger
# 135                    You must not be that this injury    sadness
# 67    You have to do something. It has become indisp...       fear
# 980   If he doesn't want to be with me, he better te...      anger
# 906                         No, she's ordering her life    neutral
# 473             We tried, but she fell into a hysteria.      anger
# 430                    I certainly come up with lodges.    sadness
# 18    Even the last times she had raised rags for 20...      anger
# 747                                              Should    sadness
# 131                          I also thought it might be    neutral
# 142                        My defense was in the store.    neutral
# 969                                    It won't be now.    sadness
# 854          to come with her to consult a psychologist  happiness
# 918                 At home are problems to be resolved    neutral
# 1008             From time to time he starts screaming.    neutral
# 881            My mother has become a different person.   surprise
# 330               I lose Theodore because he is the man       fear
# 176                                  Leave Sasha's dog.      anger
# 909                                   No way, but calm.    neutral
# 141                                    No, by no means.    neutral
# 1     Ever since Velina's father abandoned her famil...    sadness
# 1022                          I will better affect her.    neutral
# 23    I prefer to be left without money than to figh...       fear
# 525   He didn't sit on a psychologist. She Karina ma...      anger
# 139                                    You can tell me.  happiness
# 428         This is complete absurdity. Dorina is true,      anger
# 966                              Transition to therapy.  happiness
# 138                          Ok if there is any problem  happiness
# 63     Lily, I think Velina is completely on your head.      anger
# 375                     And he manages to spoil things.      anger
# 230   You know that Nicky is allergic and we can't a...    sadness
# 503             And he happens to Veli to the daughter.    sadness
# 197   Because of Velina. We have been doing whatever...      anger
# 850                                 I just didn't think    sadness
# 37    Theodore spoke with his girlfriend in advance ...    neutral
# 75                                     Very bad bluish.      anger
# 817                          No, you won't take my dog.       fear
# 1021                           But Mom is not to blame.    neutral
# 642                             I know I can handle it,    neutral
# 285                    go out and she did not complain,   surprise
# 597   Velina, what did we understand with you about ...      anger
# 526   My daughter is not a boat, she is a little ner...  happiness
# 318                                Like normal massage.    neutral
# 358                        Because your son locked her.      anger
# 707                      Me and Velina will look at it.  happiness
# 234           That they will come to live here with us.    neutral
# 633                     No, my luggage is almost ready.    neutral
# 134                     If you men tract them a little.      anger
# 171                        I'm not going to the movies.    sadness
# 251                They quarrel again because of Velina      anger
#
#      predicted_label
# 105        happiness
# 135          neutral
# 67         happiness
# 980          neutral
# 906            anger
# 473          sadness
# 430        happiness
# 18           neutral
# 747          neutral
# 131         surprise
# 142        happiness
# 969            anger
# 854          neutral
# 918            anger
# 1008            fear
# 881          sadness
# 330          sadness
# 176          sadness
# 909        happiness
# 141            anger
# 1          happiness
# 1022       happiness
# 23         happiness
# 525          neutral
# 139          neutral
# 428         surprise
# 966          neutral
# 138          neutral
# 63         happiness
# 375          sadness
# 230            anger
# 503          neutral
# 197          neutral
# 850            anger
# 37         happiness
# 75           disgust
# 817            anger
# 1021        surprise
# 642        happiness
# 285          neutral
# 597          neutral
# 526             fear
# 318        happiness
# 358          neutral
# 707          neutral
# 234        happiness
# 633            anger
# 134          neutral
# 171            anger
# 251          sadness

# %%
# Reverse label mapping to get string labels
id2label = {v: k for k, v in label2id.items()}

# Add predictions to DataFrame
df["true_label"] = [id2label[i] for i in y_true]
df["predicted_label"] = [id2label[i] for i in y_pred]

# Mark whether prediction was correct
df["is_correct"] = df["true_label"] == df["predicted_label"]

# Save output to CSV
df[["Translation", "true_label", "predicted_label", "is_correct"]].to_csv(
    "bert_large_7_full_predictions.csv", index=False
)

print("Full predictions saved to: bert_large_7_full_predictions.csv")
# Out:
# Full predictions saved to: bert_large_7_full_predictions.csv

# %% [markdown]
# ### Predictions on the re-labeled dataset = Macro F1 - 0.65 / Weighted F1 - 0.74 | Custom Weights V2

# %%
# Load test dataset
df = pd.read_excel("group_24_url1_mapped 1.xlsx")

# Drop rows without adjusted labels
df = df.dropna(subset=["adjusted_label"])

# Define core emotions and label mappings
core_emotions = ['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness', 'surprise']
label2id = {label: i for i, label in enumerate(core_emotions)}
id2label = {i: label for label, i in label2id.items()}

# Convert true labels to integers
df["label"] = df["adjusted_label"].map(label2id)

# Tokenize sentences
tokenizer = AutoTokenizer.from_pretrained("bert_large_8")
encodings = tokenizer(
    df["Translation"].tolist(),
    truncation=True,
    padding=True,
    max_length=56,
    return_tensors="pt"
)

# Dataset wrapper
class EmotionTestDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = torch.tensor(labels)

    def __getitem__(self, idx):
        item = {k: v[idx] for k, v in self.encodings.items()}
        item["labels"] = self.labels[idx]
        return item

    def __len__(self):
        return len(self.labels)

test_dataset = EmotionTestDataset(encodings, df["label"].tolist())

# Load trained model
model = AutoModelForSequenceClassification.from_pretrained("bert_large_8")

# Run predictions
trainer = Trainer(model=model)
predictions = trainer.predict(test_dataset)
y_pred = np.argmax(predictions.predictions, axis=1)
y_true = df["label"].tolist()

# Evaluation
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=core_emotions))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=core_emotions,
            yticklabels=core_emotions)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.76      0.64      0.69       204
#      disgust       0.75      0.43      0.55         7
#         fear       0.71      0.29      0.42        34
#    happiness       0.63      0.95      0.76       140
#      neutral       0.82      0.78      0.80       408
#      sadness       0.72      0.72      0.72       119
#     surprise       0.53      0.67      0.59        24
#
#     accuracy                           0.74       936
#    macro avg       0.70      0.64      0.65       936
# weighted avg       0.76      0.74      0.74       936
